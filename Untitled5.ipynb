# %%
import requests
from bs4 import BeautifulSoup

# Function to scrape text within <p> tags from the website
def scrape_paragraphs(url, output_file):
    try:
        # Send a GET request to the website
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract text within <p> tags
        paragraphs = soup.find_all('p')
        paragraph_texts = [p.get_text(strip=True) for p in paragraphs]

        # Join the paragraphs into a single string with new lines between them
        content = '\n\n'.join(paragraph_texts)

        # Save the content to a text file
        with open(output_file, 'w', encoding='utf-8') as file:
            file.write(content)

        print(f"Content saved to {output_file}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the website: {e}")

        url = 'https://www.geeksforgeeks.org/'
output_file = 'paragraphs_content.txt'
scrape_paragraphs(url, output_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-76a205254435> in <cell line: 32>()
#      30         url = 'https://www.geeksforgeeks.org/'
#      31 output_file = 'paragraphs_content.txt'
# ---> 32 scrape_paragraphs(url, output_file)
#
# NameError: name 'url' is not defined

# %%
age = 22
print("your age is:",age)
# Out:
# your age is: 22
